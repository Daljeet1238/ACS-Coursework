# %%
import pandas as pd
import matplotlib.pyplot as mplt
we = pd.read_csv("Winnipeg_Election_Results_20240409.csv")

# %%
we
# Out:
#                  Date              Type  \
# 0     October 06 1971  General Election
# 1     October 06 1971  General Election
# 2     October 06 1971  General Election
# 3     October 06 1971  General Election
# 4     October 06 1971  General Election
# ...               ...               ...
# 3313  October 26 2022  General Election
# 3314  October 26 2022  General Election
# 3315  October 26 2022  General Election
# 3316  October 26 2022  General Election
# 3317  October 26 2022  General Election
#
#                                        Area Ward          Candidate  \
# 0     Transcona-Springfield School Division    1             SOSIAK
# 1                   Norwood School Division  NaN            KENNEDY
# 2            Winnipeg School Division No. 1    2              FRITH
# 3                                Ross House  NaN      George MUNROE
# 4                             Kildonan Park  NaN               BASS
# ...

# %%
we.head
# Out:
# <bound method NDFrame.head of                  Date              Type  \
# 0     October 06 1971  General Election
# 1     October 06 1971  General Election
# 2     October 06 1971  General Election
# 3     October 06 1971  General Election
# 4     October 06 1971  General Election
# ...               ...               ...
# 3313  October 26 2022  General Election
# 3314  October 26 2022  General Election
# 3315  October 26 2022  General Election
# 3316  October 26 2022  General Election
# 3317  October 26 2022  General Election
#
#                                        Area Ward          Candidate  \
# 0     Transcona-Springfield School Division    1             SOSIAK
# 1                   Norwood School Division  NaN            KENNEDY
# 2            Winnipeg School Division No. 1    2              FRITH
# 3                                Ross House  NaN      George MUNROE
# 4                             Kildonan Park  NaN               BASS
# ...

# %%
we.head()
# Out:
#               Date              Type                                   Area  \
# 0  October 06 1971  General Election  Transcona-Springfield School Division
# 1  October 06 1971  General Election                Norwood School Division
# 2  October 06 1971  General Election         Winnipeg School Division No. 1
# 3  October 06 1971  General Election                             Ross House
# 4  October 06 1971  General Election                          Kildonan Park
#
#   Ward      Candidate                  Position   Votes  Won
# 0    1         SOSIAK  Office of School Trustee  2665.0   No
# 1  NaN        KENNEDY  Office of School Trustee  4535.0  Yes
# 2    2          FRITH  Office of School Trustee  6471.0   No
# 3  NaN  George MUNROE      Office of Councillor  1302.0  Yes
# 4  NaN           BASS      Office of Councillor   290.0   No

# %%
candidate = pd.read_csv("Winnipeg_Election_Results_20240409.csv" , index_col = 'Candidate')

# %%
candidate
# Out:
#                               Date              Type  \
# Candidate
# SOSIAK             October 06 1971  General Election
# KENNEDY            October 06 1971  General Election
# FRITH              October 06 1971  General Election
# George MUNROE      October 06 1971  General Election
# BASS               October 06 1971  General Election
# ...                            ...               ...
# Ann EVANGELISTA    October 26 2022  General Election
# Linda SCHATKOWSKY  October 26 2022  General Election
# Parm DHILLON       October 26 2022  General Election
# Dana BROWN         October 26 2022  General Election
# Gagandeep CHAHAL   October 26 2022  General Election
#
#                                                     Area Ward  \
# Candidate
# SOSIAK             Transcona-Springfield School Division    1
# KENNEDY                          Norwood School Division  NaN
# FRITH                     Winnipeg School Division No. 1    2
# ...

# %%
count_wards = we["Ward"].value_counts()

# %%
count_wards
# Out:
# Ward
# 3                              501
# 2                              476
# 1                              383
# King Edward-Deer Lodge Ward     82
# 4                               82
# Kirkfield-St. Charles Ward      68
# Silver Heights-Booth Ward       65
# 5                               29
# 9                               12
# 7                                9
# 8                                9
# 6                                7
# East Ward                        5
# West Ward                        5
# Centre Ward                      4
# Name: count, dtype: int64

# %%
fig, ax = mplt.subplots()

ax.bar(count_wards.index, count_wards)
mplt.xticks(rotation=45, ha='right')
mplt.show()

# %%
we
# Out:
#                  Date              Type  \
# 0     October 06 1971  General Election
# 1     October 06 1971  General Election
# 2     October 06 1971  General Election
# 3     October 06 1971  General Election
# 4     October 06 1971  General Election
# ...               ...               ...
# 3313  October 26 2022  General Election
# 3314  October 26 2022  General Election
# 3315  October 26 2022  General Election
# 3316  October 26 2022  General Election
# 3317  October 26 2022  General Election
#
#                                        Area Ward          Candidate  \
# 0     Transcona-Springfield School Division    1             SOSIAK
# 1                   Norwood School Division  NaN            KENNEDY
# 2            Winnipeg School Division No. 1    2              FRITH
# 3                                Ross House  NaN      George MUNROE
# 4                             Kildonan Park  NaN               BASS
# ...

# %%
count_area = we["Area"].value_counts()[:10]

# %%
count_area
# Out:
# Area
# Winnipeg School Division                395
# St. James-Assiniboia School Division    248
# Seven Oaks School Division              235
# River East School Division              168
# Winnipeg                                140
# Louis Riel School Division              137
# St. Vital School Division               135
# Fort Garry School Division              129
# River East Transcona School Division    107
# Assiniboine South School Division       100
# Name: count, dtype: int64

# %%
fig, ax = mplt.subplots()

ax.bar(count_area.index, count_area)
mplt.xticks(rotation=45, ha='right')
mplt.show()

# %%
we
# Out:
#                  Date              Type  \
# 0     October 06 1971  General Election
# 1     October 06 1971  General Election
# 2     October 06 1971  General Election
# 3     October 06 1971  General Election
# 4     October 06 1971  General Election
# ...               ...               ...
# 3313  October 26 2022  General Election
# 3314  October 26 2022  General Election
# 3315  October 26 2022  General Election
# 3316  October 26 2022  General Election
# 3317  October 26 2022  General Election
#
#                                        Area Ward          Candidate  \
# 0     Transcona-Springfield School Division    1             SOSIAK
# 1                   Norwood School Division  NaN            KENNEDY
# 2            Winnipeg School Division No. 1    2              FRITH
# 3                                Ross House  NaN      George MUNROE
# 4                             Kildonan Park  NaN               BASS
# ...

# %%
we50 = we.head(50)
we50['Votes'].plot(kind='line', marker='o', linestyle='-')

mplt.xlabel('X-axis label')
mplt.ylabel('Y-axis label')
mplt.title('Line Graph')

mplt.show()

# %%
we50 = we.head()
we50['Votes'].plot(kind='line', marker='o', linestyle='-')

mplt.xlabel('X-axis label')
mplt.ylabel('Y-axis label')
mplt.title('Line Graph')

mplt.show()

# %%
we
# Out:
#                  Date              Type  \
# 0     October 06 1971  General Election
# 1     October 06 1971  General Election
# 2     October 06 1971  General Election
# 3     October 06 1971  General Election
# 4     October 06 1971  General Election
# ...               ...               ...
# 3313  October 26 2022  General Election
# 3314  October 26 2022  General Election
# 3315  October 26 2022  General Election
# 3316  October 26 2022  General Election
# 3317  October 26 2022  General Election
#
#                                        Area Ward          Candidate  \
# 0     Transcona-Springfield School Division    1             SOSIAK
# 1                   Norwood School Division  NaN            KENNEDY
# 2            Winnipeg School Division No. 1    2              FRITH
# 3                                Ross House  NaN      George MUNROE
# 4                             Kildonan Park  NaN               BASS
# ...

# %%
count_win = we["Won"].value_counts()

# %%
count_win
# Out:
# Won
# No     1969
# Yes    1349
# Name: count, dtype: int64
